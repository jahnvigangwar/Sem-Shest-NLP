# %%
import nltk
nltk.download('gutenberg')
nltk.download('brown')
# import re
# from nltk.book import *
# from nltk.corpus import gutenberg
# from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
#Q1: In the news genre of brown corpus, find the count of the words starting with wh, such as what,
#when, where, who and why?
cfd = nltk.ConditionalFreqDist((genre,word)for genre in brown.categories() for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
# check distribution of 5 w's 1 h
general_words = ["who", "what", "when", "where", "why", "how"]
#conditional frequency distributions with event_words
cfd.tabulate(conditions=genres, samples=general_words)
# Out:
#                   who  what  when where   why   how
#            news   268    76   128    58     9    37
#        religion   100    64    53    20    14    23
#         hobbies   103    78   119    72    10    40
# science_fiction    13    27    21    10     4    12
#         romance    89   121   126    54    34    60
#           humor    48    36    52    15     9    18

# %%
#Q2: Find the conditional frequency distribution of modals ['can', 'could', 'may', 'might', 'must', 'will']
#in all the categories of brown corpus?
cfd = nltk.ConditionalFreqDist(
              (genre, word)
          for genre in brown.categories()
          for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#                   can could   may might  must  will
#            news    93    86    66    38    50   389
#        religion    82    59    78    12    54    71
#         hobbies   268    58   131    22    83   264
# science_fiction    16    49     4    12     8    16
#         romance    74   193    11    51    45    43
#           humor    16    30     8     8     9    13

# %%
#Q3: Find the year out of the filenames in the Inaugural Address Corpus?
nltk.download('inaugural')
inaugural.fileids()
[fileid[:4] for fileid in inaugural.fileids() ]
# Out:
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# ['1789',
#  '1793',
#  '1797',
#  '1801',
#  '1805',
#  '1809',
#  '1813',
#  '1817',
#  '1821',
#  '1825',
#  '1829',
#  '1833',
#  '1837',
#  '1841',
#  '1845',
#  '1849',
#  '1853',
#  '1857',
#  '1861',
#  '1865',
#  '1869',
#  '1873',
#  '1877',
#  '1881',
#  '1885',
#  '1889',
#  '1893',
#  '1897',
#  '1901',
#  '1905',
#  '1909',
#  '1913',
#  '1917',
#  '1921',
#  '1925',
#  '1929',
#  '1933',
#  '1937',
#  '1941',
#  '1945',
#  '1949',
#  '1953',
#  '1957',
#  '1961',
#  '1965',
#  '1969',
#  '1973',
#  '1977',
#  '1981',
#  '1985',
#  '1989',
#  '1993',
#  '1997',
#  '2001',
#  '2005',
#  '2009',
#  '2013',
#  '2017',
#  '2021']

# %%
nltk.download('state_union')
#Q4: Read in the texts of the State of the Union addresses, using the state_union corpus reader.
#Count occurrences of men , women , and people in each document. What has happened to the usage
#of these words over time?
print(state_union.fileids())
#cfd for inaugral address speeches for each president showing count of words american and citizen each speech
cfd = nltk.ConditionalFreqDist((target,fileid[:4])for fileid in state_union.fileids() for w in state_union.words(fileid) for target in  ['men','women'] if w.lower().startswith(target))
#cfd.plot()
# Out:
# [nltk_data] Downloading package state_union to /root/nltk_data...
# [nltk_data]   Unzipping corpora/state_union.zip.
# ['1945-Truman.txt', '1946-Truman.txt', '1947-Truman.txt', '1948-Truman.txt', '1949-Truman.txt', '1950-Truman.txt', '1951-Truman.txt', '1953-Eisenhower.txt', '1954-Eisenhower.txt', '1955-Eisenhower.txt', '1956-Eisenhower.txt', '1957-Eisenhower.txt', '1958-Eisenhower.txt', '1959-Eisenhower.txt', '1960-Eisenhower.txt', '1961-Kennedy.txt', '1962-Kennedy.txt', '1963-Johnson.txt', '1963-Kennedy.txt', '1964-Johnson.txt', '1965-Johnson-1.txt', '1965-Johnson-2.txt', '1966-Johnson.txt', '1967-Johnson.txt', '1968-Johnson.txt', '1969-Johnson.txt', '1970-Nixon.txt', '1971-Nixon.txt', '1972-Nixon.txt', '1973-Nixon.txt', '1974-Nixon.txt', '1975-Ford.txt', '1976-Ford.txt', '1977-Ford.txt', '1978-Carter.txt', '1979-Carter.txt', '1980-Carter.txt', '1981-Reagan.txt', '1982-Reagan.txt', '1983-Reagan.txt', '1984-Reagan.txt', '1985-Reagan.txt', '1986-Reagan.txt', '1987-Reagan.txt', '1988-Reagan.txt', '1989-Bush.txt', '1990-Bush.txt', '1991-Bush-1.txt', '1991-Bush-2.txt', '1992-Bush.txt', '1993-Clinton.txt', '1994-Clinton.txt', '1995-Clinton.txt', '1996-Clinton.txt', '1997-Clinton.txt', '1998-Clinton.txt', '1999-Clinton.txt', '2000-Clinton.txt', '2001-GWBush-1.txt', '2001-GWBush-2.txt', '2002-GWBush.txt', '2003-GWBush.txt', '2004-GWBush.txt', '2005-GWBush.txt', '2006-GWBush.txt']

# %%
from nltk.corpus import wordnet as wn

# %%
#Q5: Pick a pair of texts and study the differences between them, in terms of vocabulary, vocabulary
#richness, genre, etc.

news_data = nltk.Text(news_data)
religion_data = nltk.Text(religion_data)
#trying to find common words
news_fd = nltk.FreqDist(news_data)
religion_fd = nltk.FreqDist(religion_data)
print(news_data.concordance('state'))
print(religion_data.concordance('state'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-115bbc470a18> in <module>
#       2 #richness, genre, etc.
#       3
# ----> 4 news_data = nltk.Text(news_data)
#       5 religion_data = nltk.Text(religion_data)
#       6 #trying to find common words
#
# NameError: name 'news_data' is not defined

# %%
#Q6: Write a program to find all words that occur at least three times in the Brown Corpus.
all_unique_words_brown=set(brown.words())
brown_fd=nltk.FreqDist(brown.words())
atleast_3times=[word for word in all_unique_words_brown if brown_fd[word]>2]
print(atleast_3times)
# Out:
# ['1944', 'Bey', 'Jet', 'Justice', 'clustered', 'coincided', 'taken', 'elevator', 'intensifier', 'returned', 'busts', 'Roland', 'disposed', 'unspoken', 'Igbo', 'Herold', 'quit', "1/8''", 'reflexes', 'yell', 'summoned', 'tensions', 'controlling', 'remarkable', "Joe's", 'velocity', 'complicity', 'Lover', 'plaintiffs', 'creator', 'pertaining', 'deputy', 'plump', 'Andrena', 'Magdalene', 'strain', 'Sultan', 'virgin', '$85', 'axle', 'treasurer', 'ancestor', 'End', 'forests', 'sighing', 'inquiry', 'sun', 'attainment', 'explicit', 'sullen', 'Fox', 'clearance', 'compelled', 'mentioning', 'Harpers', 'wanna', 'Willamette', 'treason', 'Hound', 'Presidential', '2-1/2', 'Ministry', 'owns', 'Ferry', 'place', 'Records', 'mistakes', 'radioactivity', 'begged', 'Manual', 'loyalty', 'cites', 'comrades', 'Fishing', 'envied', "Hetman's", 'lapse', 'Pentagon', "Secretary's", 'oneself', 'consciousness', 'enclosed', 'Peter', "That'll", 'lady', 'LD', 'sends', 'consists', 'quantitative', 'airfields', 'Cut', 'nominee', 'tumor', 'coincides', 'signals', 'singly', 'structured', 'hostilities', 'garbage', 'fierce', 'notes', 'successor', "Fosdick's", 'dreaming', 'clover', 'Thereafter', 'Thornburg', 'equate', "Spencer's", 'infinite', 'sheik', 'suburbs', 'slanted', 'homemaker', 'correspondents', "doctor's", 'designating', 'audacity', 'weakness', 'Tax', 'Laura', 'interfaith', 'blew', 'driving', 'cooperating', 'exchanges', 'deck', 'bricks', 'vote', 'defined', 'slipped', 'cooperate', 'restricted', "he's", 'cakes', 'George-Barden', 'Alex', 'twinkle', 'penance', 'You', 'largely', 'SAC', 'monkey', 'Switzerland', 'Cards', 'idol', 'rags', 'portrait', 'Lublin', 'identifiable', 'reversing', 'negative', 'classifications', 'Richard', 'Carter', 'Geraghty', 'beatnik', 'consistency', 'heavenly', 'betrayed', 'feathers', 'tall', 'worthy', 'ruling', 'Moise', 'Chris', 'Acting', 'transporting', 'Germany', '1897', 'regard', 'generated', 'Mahayana', 'organically', 'grades', '49', 'conversation', 'recent', 'directing', 'Girls', 'Spade', 'descend', 'abstracting', 'Antonio', 'Figs.', 'Evangelism', '34', 'whistle', 'innocently', 'Continuous', 'encouragement', 'owe', 'hearts', 'Confederation', 'closed', 'intercontinental', 'bedroom', 'meadow', 'none', 'Kitty', 'realized', 'Minneapolis', 'communicated', 'taper', 'Brief', 'fervor', 'yielding', 'condensation', 'poking', 'trance', 'schemes', 'neglected', 'intellect', 'facilitate', 'residence', 'wake', 'Divine', 'inflicting', 'concerto', 'Frost', 'M.', 'Mad', 'results', 'techniques', 'NCTA', 'photocathode', 'occupies', 'undeveloped', 'riding', 'paragraph', 'retardation', 'indexing', 'Sutherland', 'typical', 'equipped', 'intellectual', 'Iowa', 'drugs', 'joining', 'swinging', 'chemicals', 'undergraduate', 'dominate', 'confidential', 'adherence', 'shadow', 'Gabriel', 'Mijbil', 'biology', 'landmarks', 'cost-of-living', 'Augustine', 'Reuben', 'unequivocally', 'departures', 'Satires', "Anne's", 'hierarchy', 'Loop', 'Damn', 'Clara', 'Trenton', 'provided', 'employee', 'portion', 'snobbery', 'leaned', 'insides', 'Cried', 'proceeding', 'beveled', 'ditties', 'Somerset', 'Way', 'reinforced', 'reputedly', "hasn't", 'sorghum', 'shoulders', 'anatomical', 'scouring', 'seriousness', 'Bench', 'senseless', 'two-story', 'Holden', 'hardy', 'ducked', 'gesture', 'valves', '381', 'Sitwell', 'puppets', 'indifference', 'import', 'chiefly', 'infallible', 'catkins', 'Governor', 'soap', 'tiniest', 'serving', 'starving', 'lecturer', 'Bantus', 'clip', 'villages', 'tasks', 'inmates', "Lewis's", 'Avenue', 'rubber', 'oleophilic', 'Drunk', 'Vernon', 'weaving', 'hurrying', 'laity', 'surveillance', 'china', 'strangled', 'Drawing', 'thanked', 'sojourn', 'cement', 'Agency', 'airports', 'viewpoint', 'sentimental', 'Keith', 'ketosis', 'great', 'anybody', 'missionaries', 'squares', 'Polo', 'factories', 'spelling', 'glisten', 'rearrange', 'balloons', 'Text', 'roam', 'esthetic', 'activated', 'load', 'learns', 'Circular', 'actress', 'flowed', 'Congregational', 'Letter', 'clutch', 'factors' ...

# %%
#Q7: Write a program to generate a table of lexical diversity scores (i.e., token/type ratios) for each
#genre. Include the full set of Brown Corpus genres ( nltk.corpus.brown.categories() ). Which genre
#has the lowest diversity
brown_categories=brown.categories()
print("Category, Tokens, Types, Lexical Diversity")
for category in brown_categories:
    category_words = brown.words(categories=category)
    print(category,len(category_words),len(set(category_words)),len(category_words)/(len(set(category_words))*1.0))
# Out:
# Category, Tokens, Types, Lexical Diversity
# adventure 69342 8874 7.814063556457065
# belles_lettres 173096 18421 9.396666847619565
# editorial 61604 9890 6.22891809908999
# fiction 68488 9302 7.362717695119329
# government 70117 8181 8.570712626818237
# hobbies 82345 11935 6.899455383326351
# humor 21695 5017 4.324297388877816
# learned 181888 16859 10.788777507562726
# lore 110299 14503 7.60525408536165
# mystery 57169 6982 8.188054998567745
# news 100554 14394 6.98582742809504
# religion 39399 6373 6.182174799937235
# reviews 40704 8626 4.718757245536749
# romance 70022 8452 8.284666351159489
# science_fiction 14470 3233 4.475719146303742

# %%
#Q8: Write a function that finds the 50 most frequently occurring words of a text?
from nltk.corpus import stopwords
nltk.download('stopwords')
most_freq_50_fd=nltk.FreqDist(brown.words(categories='news'))
#fd that includes stop words
print(most_freq_50_fd.most_common(50))
words=[word for word in most_freq_50_fd]
for word in words:
    if word in stopwords.words('english') or not word.isalpha():
        most_freq_50_fd.pop(word)
#fd that excludes stop words
print(most_freq_50_fd.most_common(50))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [('the', 5580), (',', 5188), ('.', 4030), ('of', 2849), ('and', 2146), ('to', 2116), ('a', 1993), ('in', 1893), ('for', 943), ('The', 806), ('that', 802), ('``', 732), ('is', 732), ('was', 717), ("''", 702), ('on', 657), ('at', 598), ('with', 545), ('be', 526), ('by', 497), ('as', 481), ('he', 451), ('said', 402), ('his', 399), ('will', 389), ('it', 363), ('from', 344), ('are', 328), (';', 314), ('an', 300), ('has', 300), ('--', 300), ('had', 279), ('who', 268), ('have', 265), ('not', 254), ('Mrs.', 253), ('were', 252), ('this', 250), ('which', 244), ('would', 244), ('their', 219), ('been', 212), ('they', 205), ('He', 191), ('one', 184), ('I', 179), ('but', 174), ('its', 174), ('or', 173)]
# [('The', 806), ('said', 402), ('would', 244), ('He', 191), ('one', 184), ('I', 179), ('last', 161), ('two', 157), ('new', 148), ('first', 143), ('year', 138), ('A', 137), ('home', 127), ('In', 127), ('also', 120), ('It', 115), ('But', 109), ('made', 107), ('years', 102), ('time', 97), ('three', 97), ('New', 93), ('state', 90), ('President', 89), ('week', 86), ('could', 86), ('four', 73), ('man', 72), ('House', 71), ('This', 70), ('back', 69), ('members', 69), ('American', 67), ('may', 66), ('program', 66), ('work', 66), ('get', 66), ('Kennedy', 66), ('John', 65), ('school', 65), ('night', 64), ('State', 63), ('They', 62), ('meeting', 62), ('since', 61), ('per', 61), ('day', 61), ('many', 60), ('There', 58), ('United', 58)]
